# %% [markdown]
# ## 01 - Data Understanding
#
# ### Objective
#
# Understand the structure of the platforms datasets before performing data cleaning, ETL, or analysis.
#
# This notebook focuses on:
# - Understanding table structure
# - Identifying columns
# - Checking data types
# - Finding missing values
# - Detecting duplicate records
# - Evaluating whether the data can answer the project's business questions

# %% [markdown]
# ### Blinkit Data understanding

# %%
import pandas as pd

# %%
# BLINKIT 

orders1 = pd.read_csv("../data/raw/Blinkit/blinkit_orders.csv")
orders2= pd.read_csv("../data/raw/Blinkit/blinkit_order_items.csv")
product = pd.read_csv("../data/raw/Blinkit/blinkit_products.csv")
inventory = pd.read_csv("../data/raw/Blinkit/blinkit_inventory.csv")
inventory_new = pd.read_csv("../data/raw/Blinkit/blinkit_inventoryNew.csv")
delivery= pd.read_csv("../data/raw/Blinkit/blinkit_delivery_performance.csv")
customer = pd.read_csv("../data/raw/Blinkit/blinkit_customers.csv")
customer_feedback= pd.read_csv("../data/raw/Blinkit/blinkit_customer_feedback.csv")
marketing = pd.read_csv("../data/raw/Blinkit/blinkit_marketing_performance.csv")

# %%
# Orders1 Table of Blinkit
orders1.info()
print(4*"______________________")
print(orders1.shape)

print(4*"______________________")
print(orders1.isnull().sum())

print(4*"______________________")
print(orders1.nunique())

print(4*"______________________")
orders1.head()

print(4*"______________________")
print(orders1["payment_method"].unique())

print(4*"______________________")
print(orders1["delivery_status"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                5000 non-null   int64
#  1   customer_id             5000 non-null   int64
#  2   order_date              5000 non-null   str
#  3   promised_delivery_time  5000 non-null   str
#  4   actual_delivery_time    5000 non-null   str
#  5   delivery_status         5000 non-null   str
#  6   order_total             5000 non-null   float64
#  7   payment_method          5000 non-null   str
#  8   delivery_partner_id     5000 non-null   int64
#  9   store_id                5000 non-null   int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 390.8 KB
# ________________________________________________________________________________________
# (5000, 10)
# ________________________________________________________________________________________
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64
# ________________________________________________________________________________________
# order_id                  5000
# customer_id               2172
# order_date                5000
# promised_delivery_time    4999
# actual_delivery_time      5000
# delivery_status              3
# order_total               4550
# payment_method               4
# delivery_partner_id       5000
# store_id                  5000
# dtype: int64
# ________________________________________________________________________________________
# ________________________________________________________________________________________
# <StringArray>
# ['Cash', 'UPI', 'Card', 'Wallet']
# Length: 4, dtype: str
# ________________________________________________________________________________________
# <StringArray>
# ['On Time', 'Slightly Delayed', 'Significantly Delayed']
# Length: 3, dtype: str

# %%
#Orders2 Table of Blinkit
orders2.info()
print(4*"______________________")

print(orders2.shape)

print(4*"______________________")
print(orders2.isnull().sum())

print(4*"______________________")
print(orders2.nunique())
print(4*"______________________")
orders2.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    5000 non-null   int64
#  1   product_id  5000 non-null   int64
#  2   quantity    5000 non-null   int64
#  3   unit_price  5000 non-null   float64
# dtypes: float64(1), int64(3)
# memory usage: 156.4 KB
# ________________________________________________________________________________________
# (5000, 4)
# ________________________________________________________________________________________
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# dtype: int64
# ________________________________________________________________________________________
# order_id      5000
# product_id     268
# quantity         3
# unit_price     267
# dtype: int64
# ________________________________________________________________________________________
#      order_id  product_id  quantity  unit_price
# 0  1961864118      642612         3      517.03
# 1  1549769649      378676         1      881.42
# 2  9185164487      741341         2      923.84
# 3  9644738826      561860         1      874.78
# 4  5427684290      602241         2      976.55

# %%
#Product Table of Blinkit
print(product.info())
print(4*"______________________")

print(product.shape)
print(4*"______________________")

print(product.isnull().sum())
print(4*"______________________")

print(product.nunique())

print(product.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         268 non-null    int64
#  1   product_name       268 non-null    str
#  2   category           268 non-null    str
#  3   brand              268 non-null    str
#  4   price              268 non-null    float64
#  5   mrp                268 non-null    float64
#  6   margin_percentage  268 non-null    float64
#  7   shelf_life_days    268 non-null    int64
#  8   min_stock_level    268 non-null    int64
#  9   max_stock_level    268 non-null    int64
# dtypes: float64(3), int64(4), str(3)
# memory usage: 21.1 KB
# None
# ________________________________________________________________________________________
# (268, 10)
# ________________________________________________________________________________________
# product_id           0
# product_name         0
# category             0
# brand                0
# price                0
# mrp                  0
# margin_percentage    0
# shelf_life_days      0
# min_stock_level      0
# max_stock_level      0
# dtype: int64
# ________________________________________________________________________________________
# product_id           268
# product_name          51
# category              11
# brand                267
# price                267
# mrp                  268
# margin_percentage      6
# shelf_life_days        5
# min_stock_level       21
# max_stock_level       51
# dtype: int64
#    product_id product_name             category                    brand  \
# 0      153019       Onions  Fruits & Vegetables               Aurora LLC
# 1       11422     Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2      669378     Potatoes  Fruits & Vegetables          Chadha and Sons
# 3      848226     Tomatoes  Fruits & Vegetables           Barad and Sons
# 4      890623       Onions  Fruits & Vegetables  Sangha, Nagar and Varty
#
#     price      mrp  margin_percentage  shelf_life_days  min_stock_level  \
# 0  947.95  1263.93               25.0                3               13
# 1  127.16   169.55               25.0                3               20
# 2  212.14   282.85               25.0                3               23
# 3  209.59   279.45               25.0                3               10
# 4  354.52   472.69               25.0                3               27
#
#    max_stock_level
# 0               88
# 1               65
# 2               70
# 3               51
# 4               55

# %%
#Inventory Table of Blinkit
inventory.info()
print(4*"______________________")
print(inventory.shape)

print(4*"______________________")
print(inventory.isnull().sum())

print(4*"______________________")
print(inventory.nunique())

print(4*"______________________")
print(inventory.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75172 entries, 0 to 75171
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      75172 non-null  int64
#  1   date            75172 non-null  str
#  2   stock_received  75172 non-null  int64
#  3   damaged_stock   75172 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 2.3 MB
# ________________________________________________________________________________________
# (75172, 4)
# ________________________________________________________________________________________
# product_id        0
# date              0
# stock_received    0
# damaged_stock     0
# dtype: int64
# ________________________________________________________________________________________
# product_id        268
# date              600
# stock_received      4
# damaged_stock       2
# dtype: int64
# ________________________________________________________________________________________
#    product_id        date  stock_received  damaged_stock
# 0      153019  17-03-2023               4              2
# 1      848226  17-03-2023               4              2
# 2      965755  17-03-2023               1              0
# 3       39154  17-03-2023               4              0
# 4       34186  17-03-2023               3              2

# %%
#Inventory_New Table of Blinkit
inventory_new.info()
print(4*"______________________")
print(inventory_new.shape)

print(4*"______________________")
print(inventory_new.isnull().sum())

print(4*"______________________")
print(inventory_new.nunique())

print(4*"______________________")
print(inventory_new.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18105 entries, 0 to 18104
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      18105 non-null  int64
#  1   date            18105 non-null  str
#  2   stock_received  18105 non-null  int64
#  3   damaged_stock   18105 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 565.9 KB
# ________________________________________________________________________________________
# (18105, 4)
# ________________________________________________________________________________________
# product_id        0
# date              0
# stock_received    0
# damaged_stock     0
# dtype: int64
# ________________________________________________________________________________________
# product_id        268
# date               21
# stock_received      4
# damaged_stock       8
# dtype: int64
# ________________________________________________________________________________________
#    product_id    date  stock_received  damaged_stock
# 0      153019  Mar-23               4              1
# 1      848226  Mar-23               4              1
# 2      965755  Mar-23               1              0
# 3       39154  Mar-23               4              0
# 4       34186  Mar-23               3              1

# %%
#Delivery Table of Blinkit
delivery.info()
print(4*"______________________")
print(delivery.shape)

print(4*"______________________")
print(delivery.isnull().sum())

print(4*"______________________")
print(delivery.nunique())

print(4*"______________________")
print(delivery.head())

print(4*"______________________")
print(delivery["delivery_status"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               5000 non-null   int64
#  1   delivery_partner_id    5000 non-null   int64
#  2   promised_time          5000 non-null   str
#  3   actual_time            5000 non-null   str
#  4   delivery_time_minutes  5000 non-null   float64
#  5   distance_km            5000 non-null   float64
#  6   delivery_status        5000 non-null   str
#  7   reasons_if_delayed     3098 non-null   str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 312.6 KB
# ________________________________________________________________________________________
# (5000, 8)
# ________________________________________________________________________________________
# order_id                    0
# delivery_partner_id         0
# promised_time               0
# actual_time                 0
# delivery_time_minutes       0
# distance_km                 0
# delivery_status             0
# reasons_if_delayed       1902
# dtype: int64
# ________________________________________________________________________________________
# order_id                 5000
# delivery_partner_id      5000
# promised_time            4999
# actual_time              5000
# delivery_time_minutes      36
# distance_km               451
# delivery_status             3
# reasons_if_delayed          1
# dtype: int64
# ________________________________________________________________________________________
#      order_id  delivery_partner_id        promised_time          actual_time  \
# 0  1961864118                63230  2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  1549769649                14983  2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  9185164487                39859  2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  9644738826                61497  2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  5427684290                84315  2023-11-20 05:17:39  2023-11-20 05:18:39
#
#    delivery_time_minutes  distance_km delivery_status reasons_if_delayed
# 0                   -5.0         0.96         On Time                NaN
# 1                    2.0         0.98         On Time            Traffic
# 2                    4.0         3.83         On Time            Traffic
# 3                   -1.0         2.76         On Time                NaN
# 4                    1.0         2.63         On Time            Traffic
# ________________________________________________________________________________________
# <StringArray>
# ['On Time', 'Slightly Delayed', 'Significantly Delayed']
# Length: 3, dtype: str

# %%
#Customer Table of Blinkit
customer.info()
print(4*"______________________")
print(customer.shape)

print(4*"______________________")
print(customer.isnull().sum())

print(4*"______________________")
print(customer.nunique())

print(4*"______________________")
print(customer.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        2500 non-null   int64
#  1   customer_name      2500 non-null   str
#  2   email              2500 non-null   str
#  3   phone              2500 non-null   int64
#  4   address            2500 non-null   str
#  5   area               2500 non-null   str
#  6   pincode            2500 non-null   int64
#  7   registration_date  2500 non-null   str
#  8   customer_segment   2500 non-null   str
#  9   total_orders       2500 non-null   int64
#  10  avg_order_value    2500 non-null   float64
# dtypes: float64(1), int64(4), str(6)
# memory usage: 215.0 KB
# ________________________________________________________________________________________
# (2500, 11)
# ________________________________________________________________________________________
# customer_id          0
# customer_name        0
# email                0
# phone                0
# address              0
# area                 0
# pincode              0
# registration_date    0
# customer_segment     0
# total_orders         0
# avg_order_value      0
# dtype: int64
# ________________________________________________________________________________________
# customer_id          2500
# customer_name        2491
# email                2496
# phone                2500
# address              2500
# area                  316
# pincode              2494
# registration_date     589
# customer_segment        4
# total_orders           20
# avg_order_value      2487
# dtype: int64
# ________________________________________________________________________________________
#    customer_id  customer_name                     email         phone  \
# 0     97475543  Niharika Nagi    ektataneja@example.org  912987579691
# 1     22077605   Megha Sachar      vedant45@example.com  915123179717
# 2     47822591     Hema Bahri     samiazaan@example.com  910034076149
# 3     79726146     Zaitra Vig     ishanvi87@example.org  916264232390
# 4     57102800   Januja Verma  atideshpande@example.org  917293526596
#
#                                address          area  pincode  \
# 0  23, Nayar Path, Bihar Sharif-154625         Udupi   321865
# 1  51/302, Buch Chowk\nSrinagar-570271       Aligarh   149394
# 2   941\nAnne Street, Darbhanga 186125     Begusarai   621411
# 3       43/94, Ghosh, Alappuzha 635655     Kozhikode   826054
# 4             06\nOm, Ambarnath 477463  Ichalkaranji   730539
#
#   registration_date customer_segment  total_orders  avg_order_value
# 0        2023-05-13          Premium            13           451.92
# 1        2024-06-18         Inactive             4           825.48
# 2        2024-09-25          Regular            17          1969.81
# 3        2023-10-04              New             4           220.09
# 4        2024-03-22         Inactive            14           578.14

# %%
#Customer feedback  Table of Blinkit
customer_feedback.info()
print(4*"______________________")
print(customer_feedback.shape)

print(4*"______________________")
print(customer_feedback.isnull().sum())

print(4*"______________________")
print(customer_feedback.nunique())

print(4*"______________________")
print(customer_feedback.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   feedback_id        5000 non-null   int64
#  1   order_id           5000 non-null   int64
#  2   customer_id        5000 non-null   int64
#  3   rating             5000 non-null   int64
#  4   feedback_text      5000 non-null   str
#  5   feedback_category  5000 non-null   str
#  6   sentiment          5000 non-null   str
#  7   feedback_date      5000 non-null   str
# dtypes: int64(4), str(4)
# memory usage: 312.6 KB
# ________________________________________________________________________________________
# (5000, 8)
# ________________________________________________________________________________________
# feedback_id          0
# order_id             0
# customer_id          0
# rating               0
# feedback_text        0
# feedback_category    0
# sentiment            0
# feedback_date        0
# dtype: int64
# ________________________________________________________________________________________
# feedback_id          5000
# order_id             5000
# customer_id          2172
# rating                  5
# feedback_text          25
# feedback_category       4
# sentiment               3
# feedback_date         600
# dtype: int64
# ________________________________________________________________________________________
#    feedback_id    order_id  customer_id  rating  \
# 0      2234710  1961864118     30065862       4
# 1      5450964  1549769649      9573071       3
# 2       482108  9185164487     45477575       3
# 3      4823104  9644738826     88067569       4
# 4      3537464  5427684290     83298567       3
#
#                           feedback_text feedback_category sentiment  \
# 0         It was okay, nothing special.          Delivery   Neutral
# 1              The order was incorrect.    App Experience  Negative
# 2         It was okay, nothing special.    App Experience   Neutral
# 3      The product met my expectations.    App Experience   Neutral
# 4  Product was damaged during delivery.          Delivery  Negative
#
#   feedback_date
# 0    2024-07-17
# 1    2024-05-28
# 2    2024-09-23
# 3    2023-11-24
# 4    2023-11-20

# %%
#Marketing Table of Blinkit
marketing.info()
print(4*"______________________")
print(marketing.shape)

print(4*"______________________")
print(marketing.isnull().sum())

print(4*"______________________")
print(marketing.nunique())

print(4*"______________________")
print(marketing.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   campaign_id        5400 non-null   int64
#  1   campaign_name      5400 non-null   str
#  2   date               5400 non-null   str
#  3   target_audience    5400 non-null   str
#  4   channel            5400 non-null   str
#  5   impressions        5400 non-null   int64
#  6   clicks             5400 non-null   int64
#  7   conversions        5400 non-null   int64
#  8   spend              5400 non-null   float64
#  9   revenue_generated  5400 non-null   float64
#  10  roas               5400 non-null   float64
# dtypes: float64(3), int64(4), str(4)
# memory usage: 464.2 KB
# ________________________________________________________________________________________
# (5400, 11)
# ________________________________________________________________________________________
# campaign_id          0
# campaign_name        0
# date                 0
# target_audience      0
# channel              0
# impressions          0
# clicks               0
# conversions          0
# spend                0
# revenue_generated    0
# roas                 0
# dtype: int64
# ________________________________________________________________________________________
# campaign_id          5400
# campaign_name           9
# date                  600
# target_audience         4
# channel                 4
# impressions          4058
# clicks                899
# conversions            91
# spend                5356
# revenue_generated    5386
# roas                  251
# dtype: int64
# ________________________________________________________________________________________
#    campaign_id      campaign_name        date target_audience channel  \
# 0       548299  New User Discount  2024-11-05         Premium     App
# 1       390914    Weekend Special  2024-11-05        Inactive     App
# 2       834385     Festival Offer  2024-11-05        Inactive   Email
# 3       241523         Flash Sale  2024-11-05        Inactive     SMS
# 4       595111   Membership Drive  2024-11-05       New Users   Email
#
#    impressions  clicks  conversions    spend  revenue_generated  roas
# 0         3130     163           78  1431.85            4777.75  3.60
# 1         3925     494           45  4506.34            6238.11  2.98
# 2         7012     370           78  4524.23            2621.00  2.95
# 3         1115     579           86  3622.79            2955.00  2.84
# 4         7172     795           54  2888.99            8951.81  2.22

# %% [markdown]
# ### Zepto

# %%
# Zepto 
Z_orders = pd.read_csv("../data/raw/Zepto/zepto_order.csv")
Z_product = pd.read_csv("../data/raw/Zepto/zepto_product.csv")
Z_delivery= pd.read_csv("../data/raw/Zepto/zepto_delivery.csv")
Z_customer = pd.read_csv("../data/raw/Zepto/zepto_customer.csv")
Z_rating = pd.read_csv("../data/raw/Zepto/zepto_rating.csv")
Z_transaction= pd.read_csv("../data/raw/Zepto/zepto_transaction.csv")

# %%
# Orders Table of Zepto
Z_orders.info()
print(4*"______________________")
print(Z_orders.shape)

print(4*"______________________")
print(Z_orders.isnull().sum())

print(4*"______________________")
print(Z_orders.nunique())

print(4*"______________________")
print(Z_orders.head())

print(4*"______________________")
print(Z_orders["order_status"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      20000 non-null  str
#  1   customer_id   20000 non-null  str
#  2   order_date    20000 non-null  str
#  3   order_status  20000 non-null  str
# dtypes: str(4)
# memory usage: 625.1 KB
# ________________________________________________________________________________________
# (20000, 4)
# ________________________________________________________________________________________
# order_id        0
# customer_id     0
# order_date      0
# order_status    0
# dtype: int64
# ________________________________________________________________________________________
# order_id        20000
# customer_id      8681
# order_date        731
# order_status        4
# dtype: int64
# ________________________________________________________________________________________
#   order_id customer_id           order_date order_status
# 0  O000001      C09732  2024-03-24 00:00:00    Delivered
# 1  O000002      C06239  2023-06-27 00:00:00    Delivered
# 2  O000003      C08023  2023-04-07 00:00:00    Delivered
# 3  O000004      C01051  2024-03-19 00:00:00    Cancelled
# 4  O000005      C02847  2024-02-21 00:00:00    Delivered
# ________________________________________________________________________________________
# <StringArray>
# ['Delivered', 'Cancelled', 'Out for Delivery', 'Returned']
# Length: 4, dtype: str

# %%
# Product Table of Zepto
Z_product.info()
print(4*"______________________")
print(Z_product.shape)

print(4*"______________________")
print(Z_product.isnull().sum())

print(4*"______________________")
print(Z_product.nunique())

print(4*"______________________")
print(Z_product.head())

#Check product_name, sub_category, category name standardization
print(4*"______________________")
print(Z_product["product_name"].unique())

print(4*"______________________")
print(Z_product["sub_category"].unique())

print(4*"______________________")
print(Z_product["category"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1200 non-null   str
#  1   product_name  1200 non-null   str
#  2   category      1200 non-null   str
#  3   sub_category  1200 non-null   str
#  4   price         1200 non-null   int64
# dtypes: int64(1), str(4)
# memory usage: 47.0 KB
# ________________________________________________________________________________________
# (1200, 5)
# ________________________________________________________________________________________
# product_id      0
# product_name    0
# category        0
# sub_category    0
# price           0
# dtype: int64
# ________________________________________________________________________________________
# product_id      1200
# product_name     906
# category           8
# sub_category      29
# price             77
# dtype: int64
# ________________________________________________________________________________________
#   product_id          product_name                category  sub_category  \
# 0     P00001    Daily Dishwash 1kg  Snacks & Branded Foods  Instant Food
# 1     P00002      Quick Apple 500g     Fruits & Vegetables  Fresh Fruits
# 2     P00003   Fresh Cashew 12 pcs           Personal Care     Skin Care
# 3     P00004  Quick Toor Dal 500ml       Grocery & Staples  Dal & Pulses
# 4     P00005    Fresh Chocolate 1L               Household   Disposables
#
#    price
# 0    250
# 1     90
# 2    100
# 3    300
# 4    180
# ________________________________________________________________________________________
# <StringArray>
# [    'Daily Dishwash 1kg',       'Quick Apple 500g',    'Fresh Cashew 12 pcs',
#    'Quick Toor Dal 500ml',     'Fresh Chocolate 1L',        'Fresh Tea 500ml',
#  'Quick Floor Cleaner 1L',         'Pure Tomato 1L',     'Pure Banana 12 pcs',
#       'Fresh Potato 200g',
#  ...
#      'Fresh Dishwash 1kg',  'Quick Dishwash 12 pcs',  'Happy Toothpaste 500g',
#    'Metro Chocolate 200g',       'Daily Potato 1kg',         'Good Apple 1kg',
#    'Quick Almonds 12 pcs',      'Daily Banana 200g',     'Daily Coffee 6 pcs',
#         'Happy Tea 6 pcs']
# Length: 906, dtype: str
# ________________________________________________________________________________________
# <StringArray>
# [      'Instant Food',       'Fresh Fruits',          'Skin Care',
#        'Dal & Pulses',        'Disposables',             'Juices',
#           'Baby Food',      'Energy Drinks',          'Oral Care',
#         'Soft Drinks',   'Fresh Vegetables', 'Biscuits & Cookies',
#        'Atta & Flour',    'Chips & Namkeen',               'Milk',
#       'Curd & Yogurt',             'Breads',  'Cleaning Supplies',
#               'Cakes',            'Diapers',          'Hair Care',
#              'Paneer',     'Baby Skin Care',    'Deos & Perfumes',
#               'Herbs',       'Tea & Coffee',            'Laundry',
#                'Rice',         'Dry Fruits']
# Length: 29, dtype: str
# ________________________________________________________________________________________
# <StringArray>
# ['Snacks & Branded Foods',    'Fruits & Vegetables',          'Personal Care',
#       'Grocery & Staples',              'Household',              'Beverages',
#               'Baby Care',         'Dairy & Bakery']
# Length: 8, dtype: str

# %%
# Delivery Table of Zepto
Z_delivery.info()
print(4*"______________________")
print(Z_delivery.shape)

print(4*"______________________")
print(Z_delivery.isnull().sum())

print(4*"______________________")
print(Z_delivery.nunique())

print(4*"______________________")
print(Z_delivery.head())

print(4*"______________________")
print(Z_delivery["delivery_status"].unique())

# missing order id check between orders and delivery table
print(4*"______________________")
all_present = orders1['order_id'].isin(Z_delivery['order_id']).all()

if all_present:
    print("✅ Success! All  order_ids from the order table are present in the delivery table.")
else:
    print("❌ Match Failed! Some order_ids are missing from the delivery table.")
    missing_in_delivery = orders1[~orders1['order_id'].isin(Z_delivery['order_id'])]['order_id']
    print(f"Total missing orders: {len(missing_in_delivery)}")
    # print("First few missing IDs:\n", missing_in_delivery.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   delivery_id         20000 non-null  str
#  1   order_id            20000 non-null  str
#  2   delivery_time_mins  20000 non-null  int64
#  3   delivery_status     20000 non-null  str
#  4   distance_km         20000 non-null  float64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 781.4 KB
# ________________________________________________________________________________________
# (20000, 5)
# ________________________________________________________________________________________
# delivery_id           0
# order_id              0
# delivery_time_mins    0
# delivery_status       0
# distance_km           0
# dtype: int64
# ________________________________________________________________________________________
# delivery_id           20000
# order_id              20000
# delivery_time_mins      103
# delivery_status           2
# distance_km              96
# dtype: int64
# ________________________________________________________________________________________
#   delivery_id order_id  delivery_time_mins    delivery_status  distance_km
# 0     D000001  O000001                  52     Delivered Late          5.0
# 1     D000002  O000002                  66     Delivered Late          6.5
# 2     D000003  O000003                  31  Delivered On Time          6.5
# 3     D000004  O000004                  68  Delivered On Time          7.7
# 4     D000005  O000005                  44     Delivered Late          7.1
# ________________________________________________________________________________________
# <StringArray>
# ['Delivered Late', 'Delivered On Time']
# Length: 2, dtype: str
# ________________________________________________________________________________________
# ❌ Match Failed! Some order_ids are missing from the delivery table.
# Total missing orders: 5000

# %%
# Customer Table of Zepto
Z_customer.info()
print(4*"______________________")
print(Z_customer.shape)

print(4*"______________________")
print(Z_customer.isnull().sum())

print(4*"______________________")
print(Z_customer.nunique())

print(4*"______________________")
print(Z_customer.head())

#check gender, city , state standardization 
print(4*"______________________")
print(Z_customer["gender"].unique())

print(4*"______________________")
print(Z_customer["city"].unique())

print(4*"______________________")
print(Z_customer["state"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    10000 non-null  str
#  1   customer_name  10000 non-null  str
#  2   email          10000 non-null  str
#  3   gender         10000 non-null  str
#  4   age            10000 non-null  int64
#  5   city           10000 non-null  str
#  6   state          10000 non-null  str
#  7   created_date   10000 non-null  str
# dtypes: int64(1), str(7)
# memory usage: 625.1 KB
# ________________________________________________________________________________________
# (10000, 8)
# ________________________________________________________________________________________
# customer_id      0
# customer_name    0
# email            0
# gender           0
# age              0
# city             0
# state            0
# created_date     0
# dtype: int64
# ________________________________________________________________________________________
# customer_id      10000
# customer_name      200
# email             9971
# gender               3
# age                 43
# city                10
# state                9
# created_date       731
# dtype: int64
# ________________________________________________________________________________________
#   customer_id  customer_name                        email gender  age  \
# 0      C00001  Vihaan Sharma  vihaan.sharma4507@gmail.com   Male   26
# 1      C00002    Meera Verma    meera.verma9675@gmail.com   Male   19
# 2      C00003    Kabir Singh    kabir.singh9864@gmail.com   Male   30
# 3      C00004     Kabir Jain     kabir.jain9655@gmail.com   Male   18
# 4      C00005    Kriti Yadav    kriti.yadav4553@gmail.com   Male   39
#
#         city      state created_date
# 0      Delhi      Delhi   2024-11-23
# 1      Delhi      Delhi   2023-08-12
# 2     Jaipur  Rajasthan   2024-03-05
# 3  Bengaluru  Karnataka   2024-12-15
# 4      Delhi      Delhi   2023-04-05
# ________________________________________________________________________________________
# <StringArray>
# ['Male', 'Female', 'Other']
# Length: 3, dtype: str
# ________________________________________________________________________________________
# <StringArray>
# [    'Delhi',    'Jaipur', 'Bengaluru',   'Chennai',    'Mumbai',   'Kolkata',
#    'Lucknow', 'Ahmedabad',      'Pune', 'Hyderabad']
# Length: 10, dtype: str
# ________________________________________________________________________________________
# <StringArray>
# [        'Delhi',     'Rajasthan',     'Karnataka',    'Tamil Nadu',
#    'Maharashtra',   'West Bengal', 'Uttar Pradesh',       'Gujarat',
#      'Telangana']
# Length: 9, dtype: str

# %%
# Rating Table of Zepto
Z_rating.info()
print(4*"______________________")
print(Z_rating.shape)

print(4*"______________________")
print(Z_rating.isnull().sum())

print(4*"______________________")
print(Z_rating.nunique())

print(4*"______________________")
print(Z_rating.head())

#check review standardization
print(4*"______________________")
print(Z_rating["review"].unique())

#check all order_ids from orders table are present in rating table
print(4*"______________________")
all_present = orders1['order_id'].isin(Z_rating['order_id']).all()

if all_present:
    print("✅ Success! All order_ids from the order table are present in the rating table.")
else:
    print("❌ Match Failed! Some order_ids are missing from the rating table.")
    
    missing_in_rating =set(orders1[~orders1['order_id'].isin(Z_rating['order_id'])]['order_id'])
    print(f"Total missing orders: {len(missing_in_rating)}")
    # print("First few missing IDs:\n", missing_in_rating.head())
  
    
#check all order_ids from delivery table are present in rating table
print(4*"______________________")
all_present = Z_delivery['order_id'].isin(Z_rating['order_id']).all()

if all_present:
    print("✅ Success! All order_ids from the order table are present in the rating table.")
else:
    print("❌ Match Failed! Some order_ids are missing from the rating table.")
    delivery_missing_in_rating = Z_delivery[~Z_delivery['order_id'].isin(Z_rating['order_id'])]['order_id']
    print(f"Total missing orders: {len(delivery_missing_in_rating)}")
    # print("First few missing IDs:\n", delivery_missing_in_rating.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rating_id  20000 non-null  str
#  1   order_id   20000 non-null  str
#  2   rating     20000 non-null  int64
#  3   review     20000 non-null  str
# dtypes: int64(1), str(3)
# memory usage: 625.1 KB
# ________________________________________________________________________________________
# (20000, 4)
# ________________________________________________________________________________________
# rating_id    0
# order_id     0
# rating       0
# review       0
# dtype: int64
# ________________________________________________________________________________________
# rating_id    20000
# order_id     12555
# rating           5
# review          13
# dtype: int64
# ________________________________________________________________________________________
#   rating_id order_id  rating                               review
# 0   R000001  O008814       5      On-time delivery, good quality.
# 1   R000002  O017887       5  All items were available and fresh.
# 2   R000003  O011133       5      On-time delivery, good quality.
# 3   R000004  O012215       2                  Items were damaged.
# 4   R000005  O015223       5  All items were available and fresh.
# ________________________________________________________________________________________
# <StringArray>
# [         'On-time delivery, good quality.',
#       'All items were available and fresh.',
#                       'Items were damaged.',
#      'Average experience, could be better.',
#                 'Loved the quick delivery.',
#            'Great experience, fresh items.',
#          'Nice packaging and fast service.',
#            'Delivery was slightly delayed.',
#                 'Poor quality and service.',
#                             'Okay service.',
#  'Very bad experience, not ordering again.',
#          'Late delivery and missing items.',
#       'One or two items were not so fresh.']
# Length: 13, dtype: str
# ________________________________________________________________________________________
# ❌ Match Failed! Some order_ids are missing from the rating table.
# Total missing orders: 5000
# ________________________________________________________________________________________
# ❌ Match Failed! Some order_ids are missing from the rating table.
# Total missing orders: 7445

# %%
# Transaction Table of Zepto
Z_transaction.info()
print(4*"______________________")
print(Z_transaction.shape)

print(4*"______________________")
print(Z_transaction.isnull().sum())

print(4*"______________________")
print(Z_transaction.nunique())

print(4*"______________________")
Z_transaction.head()

print(4*"______________________")
print(Z_transaction["payment_mode"].unique())

#check all order_ids from orders table are present in transaction table
print(4*"______________________")
all_present = orders1['order_id'].isin(Z_transaction['order_id']).all()

if all_present:
    print("✅ Success! All order_ids from the order table are present in the transaction table.")
else:
    print("❌ Match Failed! Some order_ids are missing from the transaction table.")
    missing_in_transaction = set(orders1[~orders1['order_id'].isin(Z_transaction['order_id'])]['order_id'])
    print(f"Total missing orders: {len(missing_in_transaction)}")
    # print("First few missing IDs:\n", missing_in_transaction.head())

# check missing order id are same or not between rating and transaction
print(4*"______________________")
if missing_in_rating == missing_in_transaction:
    print("✅ both table have same missing order ids")
else:
    print("❌both table have different missing order ids or something else.")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  50000 non-null  str
#  1   order_id        50000 non-null  str
#  2   product_id      50000 non-null  str
#  3   quantity        50000 non-null  int64
#  4   amount          50000 non-null  int64
#  5   payment_mode    50000 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 2.3 MB
# ________________________________________________________________________________________
# (50000, 6)
# ________________________________________________________________________________________
# transaction_id    0
# order_id          0
# product_id        0
# quantity          0
# amount            0
# payment_mode      0
# dtype: int64
# ________________________________________________________________________________________
# transaction_id    50000
# order_id          18372
# product_id         1200
# quantity              5
# amount              227
# payment_mode          6
# dtype: int64
# ________________________________________________________________________________________
# ________________________________________________________________________________________
# <StringArray>
# ['UPI', 'Debit Card', 'Credit Card', 'Cash on Delivery', 'Wallet',
#  'Net Banking']
# Length: 6, dtype: str
# ________________________________________________________________________________________
# ❌ Match Failed! Some order_ids are missing from the transaction table.
# Total missing orders: 5000
# ________________________________________________________________________________________
# ✅ both table have same missing order ids

# %% [markdown]
# ### Swiggy Instamart
